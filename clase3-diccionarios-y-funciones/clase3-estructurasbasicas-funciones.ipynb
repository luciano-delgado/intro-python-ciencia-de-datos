# %% [markdown]
# **Clase 3 - 03/05/2024: Estructuras básicas y Funciones ⚡🐍**

# %% [markdown]
# # **Diccionarios y Tuplas. Conversiones de Tipos**

# %% [markdown]
# **1) Diccionarios**
#
# Son una estructura (objeto) que almacenan una palabra clave `key` y el valor `value` correspondiente.
#
# - Las claves son únicas y pueden ser `string/int/float/tuplas` (entre otros)
# - Son estructuras versátiles que admiten distintos tipos de datos.
# - Indexación por rango numérico (se puede acceder a sus `elementos`)
# - Son Mutables

# %% [markdown]
# 1.1) Diccionario vacío. Diccionario con claves `string/int`

# %%
# Vacío
mi_dict = {}
print(mi_dict)
# Out:
# {}

# %%
mi_dict = {
    'nombre': 'Guido',          # Clave 1 : Valor 1
    'apellido': 'Van Rossum',   # Clave 2 : Valor 2
    'edad': 50,                 # Clave 3 : Valor 3
    'programador': True         # Clave 4 : Valor 4
}
print(mi_dict)
# Out:
# {'nombre': 'Guido', 'apellido': 'Van Rossum', 'edad': 50, 'programador': True}

# %%
mi_dict = {
    1: 'Python',          # Clave 1 : Valor 1
    2: 'SQL',             # Clave 2 : Valor 2
    3: 'Java'             # Clave 3 : Valor 3
}
print(mi_dict)
# Out:
# {1: 'Python', 2: 'SQL', 3: 'Java'}

# %% [markdown]
# **2.2) Métodos para Diccionarios**

# %% [markdown]
# 2.2.1) Obtener un elemento. (Notación `[]` & método `get()`)

# %%
# Notación de []
dict = {
    'nombre': 'Guido',          # Clave 1 : Valor 1
    'apellido': 'Van Rossum',   # Clave 2 : Valor 2
    'edad': 50,                 # Clave 3 : Valor 3
    'programador': True         # Clave 4 : Valor 4
}
nombre = dict['nombre']
print(f'El valor de la clave "nombre" de mi diccionario es: {nombre}')
# Out:
# El valor de la clave "nombre" de mi diccionario es Guido

# %% [markdown]
# Nota: Es necesario conocer el nombre de la `clave`. Si buscáramos `dict['altura']` daría error.

# %%
# Método `get()`
print(dict.get('apellido'))
# Out:
# Van Rossum

# %% [markdown]
# Nota: Si no encuentra el valor, la función devuelve `False` (es posible modificar ese `valor por defecto`)

# %%
print(dict.get('altura', 'Clave no encontrada'))
# Out:
# Clave no encontrada

# %% [markdown]
# 2.2.2) Añadir o modificar un elemento: Notación `[]`

# %%
dict = {'nombre' : 'Guido',
        'altura': 1.75
        }
# Si existe, lo reemplaza
dict['altura'] = 1.80
print(dict)
# Out:
# {'nombre': 'Guido', 'altura': 1.8}

# %%
# Si no existe, la agrega
dict['peso'] = '70kg'
print(dict)
# Out:
# {'nombre': 'Guido', 'altura': 1.8, 'peso': '70kg'}

# %% [markdown]
# 2.2.3) Pertenencia de una clave: `in` & `not in`

# %%
dict = {'nombre' : 'Guido',
        'altura': 1.75
        }
print('nombre' in dict)
print('nombre' not in dict)
# Out:
# True
# False

# %% [markdown]
# 2.2.4) Obtener todas las claves/valores/pares
# - Método`keys()` para claves
# - Método `values()` para valores
# - Método `items()` para pares

# %%
dict = {'nombre' : 'Guido',
        'altura': 1.75
        }
# Todas las claves: keys()
print(dict.keys())
# Todas los valores: values()
print(dict.values())
# Todos los items
print(dict.items())
# Out:
# dict_keys(['nombre', 'altura'])
# dict_values(['Guido', 1.75])
# dict_items([('nombre', 'Guido'), ('altura', 1.75)])

# %% [markdown]
# 2.2.5) Longitud de un diccionario: `len()`

# %%
dict = {'nombre' : 'Guido',
        'altura': 1.75
        }
print(f'La longitud de mi diccionario es: {len(dict)}')
# Out:
# La longitud de mi diccionario es: 2

# %% [markdown]
# 2.2.6) Combinar diccionarios: `update()`

# %%
dict1 = {
    'nombre': 'Guido',
    'apellido': 'Van Rossum',
    'edad': 50,
    'programador': True
}
dict2 = {'nombre' : 'Guido Von Rossum',
        'altura': 1.75
        }
dict1.update(dict2)
print(dict1)
# Out:
# {'nombre': 'Guido Von Rossum', 'apellido': 'Van Rossum', 'edad': 50, 'programador': True, 'altura': 1.75}

# %% [markdown]
# Nota: Si la clave se pisa, utiliza el del 2do diccionario (ver clave `nombre`)

# %% [markdown]
# 2.2.7) Borrar elementos: `del()`

# %%
# Borrar 1 elemento
dict = {
    'nombre': 'Guido',
    'apellido': 'Van Rossum',
    'edad': 50,
    'programador': True
}
del(dict['edad'])
print(dict)
# Out:
# {'nombre': 'Guido', 'apellido': 'Van Rossum', 'programador': True}

# %%
# Borrar TODOS los elementos: clear()
print(dict.clear())
# Out:
# None

# %% [markdown]
# 2.2.8) Extraer un elemento: `pop()`

# %%
dict = {
    'nombre': 'Guido',
    'apellido': 'Van Rossum',
    'edad': 50,
    'programador': True
}
dict.pop('edad')
print(dict)
# Out:
# {'nombre': 'Guido', 'apellido': 'Van Rossum', 'programador': True}

# %% [markdown]
# 2.2.9) Copiar un diccionario: `copy()`

# %%
dict1 = {
    'nombre': 'Guido',
    'apellido': 'Van Rossum',
    'edad': 50,
    'programador': True
}
dict2 = dict1.copy()
print(dict1)
print(dict2)
# Out:
# {'nombre': 'Guido', 'apellido': 'Van Rossum', 'edad': 50, 'programador': True}
# {'nombre': 'Guido', 'apellido': 'Van Rossum', 'edad': 50, 'programador': True}

# %% [markdown]
# 2.1.10) Iterar `clave` y `valor` en un bucle for: `enumerate()`

# %%
dict = {
    'nombre': 'Guido',
    'apellido': 'Van Rossum',
    'edad': 50,
    'programador': True
}
for posicion, clave in enumerate(dict):
    print(posicion, clave)
    valor = dict[clave]
    print(valor)
# Out:
# 0 nombre
# Guido
# 1 apellido
# Van Rossum
# 2 edad
# 50
# 3 programador
# True

# %% [markdown]
# Más sobre diccionarios: https://docs.python.org/es/3/tutorial/datastructures.html#dictionaries

# %% [markdown]
# **2) Tuplas**
#
# Una tupla está formada por un número de valores separados por comas.
#
# - Versátiles: Admiten distintos tipos de datos
# - Admiten duplicados
# - INmutables (A diferencia de las `listas` y `diccionarios`)

# %% [markdown]
# 2.1) Definir una tupla

# %%
# Definición más usada
tupla1 = (1, 2, 3)
tupla2 = (1, 1, 'Guido', False, 3.14)
tupla3 = (1, 'Python', [1, 3, 5], 3.14, {'Nombre': 'Guido'})
print(tupla1)
print(tupla2)
print(tupla3)
# Out:
# (1, 2, 3)
# (1, 1, 'Guido', False, 3.14)
# (1, 'Python', [1, 3, 5], 3.14, {'Nombre': 'Guido'})

# %%
# Definición sin paréntesis
tupla = 'Guido', 'Van', 'Rossum'
print(type(tupla))
print(tupla)
# Out:
# <class 'tuple'>
# ('Guido', 'Van', 'Rossum')

# %% [markdown]
# 2.2) Métodos para `tuplas`: Podemos usar los mismos que para listas salvo aquellos que modifiquen el objeto
# recordemos que las tuplas son `INmutables`
#
# Es decir, no se puede utilizar:
# - `reverse()`
# - `append()`
# - `extend()`
# - `clear()`
# - `sort()`

# %% [markdown]
# 2.2.1) Obtener un elemento: Notación de `[]` & `index()`

# %%
tupla = (1, 3.14, 'Guido', True)
# Posición
print(f'Mi primer elemento de la tupla es: {tupla[0]}')
# Indexación
print(f'El índice de mi elemento 1 es {tupla.index(1)}')
# Out:
# Mi primer elemento de la tupla es: 1
# El índice de mi elemento 1 es 0

# %% [markdown]
# 2.2.2) Contar apariciones de un elemento: `count(elemento)`

# %%
tupla = (1, 2, 3, 3, 4, 5, 2, 2, 4, 2, 5, 2)
print(tupla.count(2))
# Out:
# 5

# %% [markdown]
# Más sobre `tuplas`: https://docs.python.org/es/3/library/stdtypes.html#tuples

# %% [markdown]
# **3) Conversiones de Tipos**

# %% [markdown]
# Veremos las conversiones más comunes y validaremos el nuevo tipo de dato con el método `type()` que vimos en la primer clase.

# %% [markdown]
# Defino una variable por cada tipo que hemos visto

# %%
string = 'Hello LVL-UP'
entero = 10
flotante = 3.14
booleano = True
lista = [1,2,'Hola', 3.14]
conjunto = {1,2,'Hola', 3.14}
tupla = (1,2,'Hola', 3.14)
diccionario = {'nombre':'Guido', 'apellido': 'Von Rossum'}

# %% [markdown]
# 3.1) Transformaciones a `string`: Método `str()`

# %%
print(str(string))
print(str(entero))
print(str(flotante))
print(str(booleano))
print(str(lista))
print(str(conjunto))
print(str(tupla))
print(str(diccionario))
print('\nValido los tipos de variables obtenidos al converstir a string: ')
print(type(str(string)))
print(type(str(entero)))
print(type(str(flotante)))
print(type(str(booleano)))
print(type(str(lista)))
print(type(str(conjunto)))
print(type(str(tupla)))
print(type(str(diccionario)))
# Out:
# Hello LVL-UP
# 10
# 3.14
# True
# [1, 2, 'Hola', 3.14]
# {'Hola', 2, 3.14, 1}
# (1, 2, 'Hola', 3.14)
# {'nombre': 'Guido', 'apellido': 'Von Rossum'}
#
# Valido los tipos de variables obtenidos al converstir a string:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# 3.2) Conversiones a int: Método `int()`

# %%
print(int(entero))
print(int(flotante))
print(int(booleano))
# Strings y estructuras compuestas: no es posible la conversión de tipo de dato en este caso
print('\nValido los tipos de variables obtenidos al convertir a int: ')
print(type(int(entero)))
print(type(int(flotante)))
print(type(int(booleano)))
# Out:
# 10
# 3
# 1
#
# Valido los tipos de variables obtenidos al convertir a int:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# 3.3) Conversiones a float: Método `float()`

# %%
print(float(entero))
print(float(flotante))
print(float(booleano))
# Strings y estructuras compuestas: no es posible la conversión de tipo de dato en este caso
print('\nValido los tipos de variables obtenidos al converstir a float: ')
print(type(float(entero)))
print(type(float(flotante)))
print(type(float(booleano)))
# Out:
# 10.0
# 3.14
# 1.0
#
# Valido los tipos de variables obtenidos al converstir a float:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# 3.4) Conversiones a booleano: Método `bool()`

# %% [markdown]
# En este caso, si la variable sea cual sea el tipo de dato está `vacio`, se convertirá en `False`. Sino en `True`

# %%
string2 = ''
entero2 = 0
flotante2 = 0
lista2=[]
conjunto2 = {}
tupla2 = ()
diccionario2 = {}
print(bool(string2))
print(bool(entero2))
print(bool(flotante2))
print(bool(lista2))
print(bool(conjunto2))
print(bool(tupla2))
print(bool(diccionario2))
print('\nValido los tipos de variables obtenidos al converstir a bool: ')
print(type(bool(string2)))
print(type(bool(entero2)))
print(type(bool(flotante2)))
print(type(bool(lista2)))
print(type(bool(conjunto2)))
print(type(bool(tupla2)))
print(type(bool(diccionario2)))
# Out:
# False
# False
# False
# False
# False
# False
# False
#
# Valido los tipos de variables obtenidos al converstir a bool:
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# Si tomáramos algunas de las variables iniciales definidas nos devolvería `True`:

# %%
print(bool(string))
print(bool(entero))
print(bool(flotante))
print(bool(lista))
# Out:
# True
# True
# True
# True

# %% [markdown]
# 3.5) Conversiones a lista: Método `list()`
#
# Nota: Deben ser tipos de datos **iterables**. Los enteros/flotantes/booleanos **no son iterables** con lo cual no puede realizarse la conversión.

# %%
print(list(string))
print(list(lista))
print(list(conjunto))
print(list(tupla))
print(list(diccionario))
print('\nValido los tipos de variables obtenidos al converstir a lista: ')
print(type(list(string)))
print(type(list(lista)))
print(type(list(conjunto)))
print(type(list(tupla)))
print(type(list(diccionario)))
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'L', 'V', 'L', '-', 'U', 'P']
# [1, 2, 'Hola', 3.14]
# ['Hola', 2, 3.14, 1]
# [1, 2, 'Hola', 3.14]
# ['nombre', 'apellido']
#
# Valido los tipos de variables obtenidos al converstir a lista:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %% [markdown]
# 3.6) Converiones a conjuntos: Método `set()`.
#
# Nota: Deben ser tipos de datos **iterables**. Los enteros/flotantes/booleanos **no son iterables** con lo cual no puede realizarse la conversión.

# %%
print(set(string))
print(set(lista))
print(set(conjunto))
print(set(tupla))
print(set(diccionario))
print('\nValido los tipos de variables obtenidos al convertir a conjunto: ')
print(type(set(string)))
print(type(set(lista)))
print(type(set(conjunto)))
print(type(set(tupla)))
print(type(set(diccionario)))
# Out:
# {'H', 'e', 'P', 'U', 'l', '-', 'V', ' ', 'o', 'L'}
# {1, 2, 3.14, 'Hola'}
# {1, 2, 3.14, 'Hola'}
# {1, 2, 3.14, 'Hola'}
# {'apellido', 'nombre'}
#
# Valido los tipos de variables obtenidos al convertir a conjunto:
# <class 'set'>
# <class 'set'>
# <class 'set'>
# <class 'set'>
# <class 'set'>

# %% [markdown]
# 3.7) Conversiones a tuplas: Método `tuple()`
#
# Nota: Deben ser tipos de datos **iterables**. Los enteros/flotantes/booleanos **no son iterables** con lo cual no puede realizarse la conversión.

# %%
print(tuple(string))
print(tuple(lista))
print(tuple(conjunto))
print(tuple(tupla))
print(tuple(diccionario))
print('\nValido los tipos de variables obtenidos al convertir a tupla: ')
print(type(tuple(string)))
print(type(tuple(lista)))
print(type(tuple(conjunto)))
print(type(tuple(tupla)))
print(type(tuple(diccionario)))
# Out:
# ('H', 'e', 'l', 'l', 'o', ' ', 'L', 'V', 'L', '-', 'U', 'P')
# (1, 2, 'Hola', 3.14)
# (1, 2, 3.14, 'Hola')
# (1, 2, 'Hola', 3.14)
# ('nombre', 'apellido')
#
# Valido los tipos de variables obtenidos al convertir a tupla:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>

# %% [markdown]
# 3.8) Conversiones a diccionario: Método `dict()`
#
# Nota: Este caso es más particular se pueden convertir algunas estructuras específicas (el requisito de ser **iterables** también es condición necsaria). Veremos 3 casos:

# %% [markdown]
# 3.8.1) Convertir una `lista` de `tuplas`

# %%
lista_tuplas = [("a", 1), ("b", 2), ("c", 3)]
diccionario = dict(lista_tuplas)
print(diccionario)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# 3.8.2) Convertir dos `listas` paralelas en `diccionario`

# %%
keys = ['a', 'b', 'c']
values = [1, 2, 3]
diccionario = dict(zip(keys, values))
print(diccionario)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# 3.8.3) Convertir un conjunto de `tuplas` en un `diccionario`

# %%
conjunto_tuplas = {("a", 1), ("b", 2), ("c", 3)}
diccionario = dict(conjunto_tuplas)
print(diccionario)
# Out:
# {'b': 2, 'c': 3, 'a': 1}

# %% [markdown]
# # 📝 Ejercicios Parte 1

# %% [markdown]
# 👉 Parte 1 - Ejercicio de clase
#
# Definir una `lista` de valores numéricos (`int`y`float`) y obtener la suma total de todos los elementos, los cuales se almacenarán en una nueva variable `suma`

# %%
# Definir una lista de números
lista_numeros = [1, 22, 33, 3.14, 5.56, 323, 24]
# Inicializar una variable para almacenar la suma
suma = 0
# Iterar sobre los elementos de la lista y sumarlos
for numero in lista_numeros:
    suma += numero
# Imprimir la suma de los elementos
print("La suma de los números es:", suma)
# Out:
# La suma de los números es: 411.7

# %% [markdown]
# Nota: Esto mismo lo podríamos realizar con la función `built-in` de Python `sum()` y obtener el mismo resultado.

# %%
sum(lista_numeros)
# Out:
# 411.7

# %% [markdown]
# 🫴🏻 Parte 1 - Ejercicio de tarea 1
#
# Definir una `lista` de valores numéricos (`int`y`float`) y obtener la el valor máximo, el cual se almacenará en una nueva variable `maximo`.

# %%
# Definir una lista de números
numeros = [1, 22, 33, 3.14, 5.56, 323, 24]
# Inicializar una variable para almacenar la suma
maximo = 0
# Iterar sobre los elementos de la lista y sumarlos
for numero in numeros:
    if numero >= maximo:
      maximo = numero
    else:
      continue
# Imprimir la suma de los elementos
print("El valor máximo es:", maximo)
# Out:
# El valor máximo es: 323

# %% [markdown]
# Nota: Esto ya viene resuelto en la función `built-in` de python `max()`

# %% [markdown]
# 🫴🏻 Parte 1 - Ejercicio de tarea 2
#
# Supongamos que tenemos una lista de estudiantes y sus calificaciones en diferentes materias, representada como un `diccionario` donde la clave es el `nombre` del estudiante y el `valor` es una `lista` de calificaciones.
#
# Se pide calcular el promedio de cada estudiante y determinar si aprobaron o reprobaron cada materia, considerando que la nota mínima para aprobar es 60.
#
# `calificaciones = {
#     'Juan': [80, 75, 90],
#     'María': [65, 70, 55],
#     'Pedro': [40, 60, 70]
# }`

# %%
# Diccionario con datos de calificaciones de los estudiantes
calificaciones = {
    'Juan': [80, 75, 90],
    'María': [65, 70, 55],
    'Pedro': [40, 60, 70]
}
# Calculamos el promedio de cada estudiante y determinamos si aprueba o reprueba cada materia
for estudiante, notas in calificaciones.items():
    print(f'Analizando a {estudiante} cuyas notas son {notas}...')
    promedio = sum(notas) / len(notas)
    print(f"{estudiante}: Promedio = {promedio:.2f}")

    for i, nota in enumerate(notas):
        if nota >= 60:
            resultado = "Aprobado"
        else:
            resultado = "Reprobado"
        print(f"Materia {i+1}: {resultado}")
# Out:
# Analizando a Juan cuyas notas son [80, 75, 90]...
# Juan: Promedio = 81.67
# Materia 1: Aprobado
# Materia 2: Aprobado
# Materia 3: Aprobado
# Analizando a María cuyas notas son [65, 70, 55]...
# María: Promedio = 63.33
# Materia 1: Aprobado
# Materia 2: Aprobado
# Materia 3: Reprobado
# Analizando a Pedro cuyas notas son [40, 60, 70]...
# Pedro: Promedio = 56.67
# Materia 1: Reprobado
# Materia 2: Aprobado
# Materia 3: Aprobado

# %% [markdown]
# # Funciones 🧮

# %% [markdown]
# Estructura que nos permite agrupar código para no repetir y poder reutilizarlo.
# Está básicamente compuesta por:
# - `nombres` de la función
# - `parametros` a recibir (Luego el valor real pasado a la función se denomina `argumento`
# - `return`: Valor de retorno
#
# Para llamar a la función se utiliza el nombre seguido de paréntesis (agregándole los parámetros en caso de que reciba):
#
# `función(argumento1, argumento2)`
#
# Notas:
# - Prestar atención a la `indentación` para reflejar el código que está "dentro" de nuestra función.
# - Es importante documentar la acción realizada por la función al definirla.

# %% [markdown]
# **1) Definicion de función**
#
# - Función que no realiza acción
# - Función que recibe un parámetro
# - Función que recibe un parámetro y devuelve un resultado

# %% [markdown]
# 1.1) Funcion que no realiza acción: `pass`

# %%
# Defino función
def funcion1():
    """Función que no realiza ninguna acción
    """
    pass

# Llamo a mi función
funcion1()

# %% [markdown]
# Nota: ¿Y para qué es útil si no hace nada? Muchas veces cuando programamos, vamos armando la estructura de nuestra aplicación y definiendo las funciones y acciones que deberán realizar pero sin codearla en ese momento, con lo cual terminamos de escribirlas en un paso posterior.

# %% [markdown]
# 1.2) Función que recibe un parámetro

# %%
# Defino función
def funcion2(nombre):
    """Función que recibe como parámetro un nombre e imprime en pantalla un mensaje
    """
    print(f'Hola {nombre}!')

# Llamo a mi función
funcion2('Luciano')
# Out:
# Hola Luciano!

# %% [markdown]
# 1.3) Función que recibe 2 parámetros y retorna un valor.

# %%
# Defino función
def funcion3(nombre, edad):
    """ Función que recibe parametros de nombre, edad y retorna un mensaje con
    la categoría a la que corresponde la persona
    """
    if edad < 8:
      categoria = 'inferiores'
      mensaje = f'{nombre} estás en la categoría: {categoria}'
    elif 8 < edad < 12:
      categoria = 'intermedia'
      mensaje = f'{nombre} estás en la categoría: {categoria}'
    else:
      categoria = 'superior'
      mensaje = f'{nombre} estás en la categoría: {categoria}'

    return mensaje

# Llamo a la función y almaceno el resultado del 'return' en una variable `mensaje`
mensaje = funcion3('Luciano', 32)
# Imprimo mi variable `mensaje` que capturó el `return` de mi funcion3
print(mensaje)
# Out:
# Luciano estás en la categoría: superior

# %% [markdown]
# 1.3) Parámetros por defecto

# %% [markdown]
# En caso de que no se proporcione valor al `argumento` en la llamada a la `función`, el parametro correspondiente puede asignarse con un valor predefinido `por defecto` al definila.

# %%
def caracteristicas_persona(nombre, apellido, comida_favorita = 'Pizza'):
    """Función que recibe de parametros nombre, apellido y comida_favorita e
    imprime un mensaje en pantalla
    """
    print(f'Hola {nombre} {apellido}, tu comida favorita es: {comida_favorita}')

# LLamo a mi función sin pasar el parámetro ``comida_favorita`
caracteristicas_persona('Luciano', 'Delgado')
# LLamo a mi función `pasando el parámetro ``comida_favorita` (pisa parámetro por defecto)
caracteristicas_persona('Luciano', 'Delgado', 'Tarta de acelga')
# Out:
# Hola Luciano Delgado, tu comida favorita es: Pizza
# Hola Luciano Delgado, tu comida favorita es: Tarta de acelga

# %% [markdown]
# 1.4) Sugiriendo el tipo de `parametro` esperado
#
# Lo indicamos con ":" seguido del tipo de `parametro` al definirlo en la función.

# %%
def saludo(
    nombre:str      # Acá sugiero que el argumento a recibir debería ser `string`
    ):
  """ Funcion que recibe el parametro nombre (en el cual se sugiere que sea string)
  """
  print(f'Hola {nombre}')

# LLamo a mi función
saludo('Luciano')
# Out:
# Hola Luciano

# %% [markdown]
# ¿Qué pasa si probamos pasándole un `int`?

# %%
saludo(5)
# Out:
# Hola 5

# %% [markdown]
# Nota: Python es un lenguaje de tipado `dinámico` y `flexible`, lo que significa que no se realizan comprobaciones estrictas de tipos en tiempo de ejecución, como en algunos lenguajes estáticamente tipados.

# %% [markdown]
# **2) Argumentos de una función**

# %% [markdown]
# 2.1) Argumentos `posicionales`
#
# Se copian en sus correspondientes parámetros **en orden** (durante el llamado a la función, no impacta en su definición)
#
# Nota: Se necesita recordar el orden de los parámetros.

# %%
def armar_pc(proveedor, nucleos, frecuencia):
    """Funcion que recibe como parametros proveedor, cantidad de nubleos y frecuencia
    y retorna un diccionario con las características de mi PC.
    """
    dict = {
        "proveedor": proveedor,
        "nucleos": nucleos,
        "frecuencia": frecuencia,
        }

    return dict

# %%
# LLamado a la función pasando argumentos posicionales
resultado = armar_pc(
    'Intel',
    4,
    '80MHz'
    )
print(f'Resultado de llamada a mi función "armar_pc" pasando parametros posicionales: \n{resultado}')
# Out:
# Resultado de llamada a mi función "armar_pc" pasando parametros posicionales:
# {'proveedor': 'Intel', 'nucleos': 4, 'frecuencia': '80MHz'}

# %% [markdown]
# 2.2) Argumentos `nominales`
#
# Se asignan **por nombre** a cada parámetro (no impactan en la definición de la función)
#
# Nota: No se necesita recordar el posicionamiento al llamar a la función.

# %%
resultado = armar_pc(
    proveedor='Intel',
    nucleos=4,
    frecuencia='80MHz')

print(f'Resultado de llamada a mi función "armar_pc" pasando parametros nominales es:\n {resultado}')
# Out:
# Resultado de llamada a mi función "armar_pc" pasando parametros nominales es:
#  {'proveedor': 'Intel', 'nucleos': 4, 'frecuencia': '80MHz'}

# %% [markdown]
# 2.3) Argumentos `mixtos`
#  Los posicionales deben ir antes que los nominales, sino Python no tendría forma de discernir a qué parámetro corresponde cada argumento.

# %%
# Reutilizando la función armar_pc definida previamente
armar_pc(
    'Intel',
    nucleos=4,
    frecuencia='80MHz'
    )
# Out:
# {'proveedor': 'Intel', 'nucleos': 4, 'frecuencia': '80MHz'}

# %% [markdown]
# El siguiente código daría `error` ya que estoy pasando como argumento `posicional` posterior a uno `ordinal`.

# %%
armar_pc('Intel', nucleos = 4, '80MHz')
# Out:
#   File "<ipython-input-30-6fc78ece1007>", line 1
#     armar_pc('Intel', nucleos = 4, '80MHz')
#                                           ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# **3) Packing & Unpacking**
#
# Son formas de capturar el resultado del `return` (Valor de retorno)de una función.

# %% [markdown]
# 3.1) Packing
#
# Ocurre cuando una `función` devuelve múltiples valores y los capturamos todos juntos en una **única** `variable`.

# %% [markdown]
# 3.1.2) Ejemplo 1: retornando valores de mismo tipo

# %%
def obtener_puntos():
    """Función que devuelve dos valores enteros fijos
    """
    return 10, 20  # Retorna dos valores: 10 y 20

# Llamado con packing:
resultado1 = obtener_puntos()  # Capturamos los valores retornados en la variable 'puntos'
print(resultado1)
# Out:
# (10, 20)

# %% [markdown]
# 3.1.2) Ejemplo 2: retornando valores de distinto tipo

# %%
def obtener_condicion(condicion_binaria: str):
    """ Funcion que recibe un parámetro sugerido del tipo 'string'
    y devuelve
    """
    if condicion_binaria == 'Yes':
      return True, 1
    elif condicion_binaria == 'No':
      return False, 0
    else:
      return 'no condition'

# Llamado con packing:
resultado2 = obtener_condicion('Yes')
print(resultado2)
# Out:
# (True, 1)

# %% [markdown]
# Nota: Para el ejemplo retornamos 2 valores pero no hay límites, podrían ser 3,4,5... etc

# %% [markdown]
# ¿Cómo accedo a cada valor luego del `packing`?
# Utilizamos referencia por índice en nuestra variable empaquetada.

# %%
primer_valor_retornado = resultado2[0]
segundo_valor_retornado = resultado2[1]
print(f'Mi primer valor retornado fue: {primer_valor_retornado}')
print(f'Mi segundo valor retornado fue: {segundo_valor_retornado}')
# Out:
# Mi primer valor retornado fue: True
# Mi segundo valor retornado fue: 1

# %% [markdown]
# 3.2) Unpacking
#
# Ocurre cuando una `función` devuelve múltiples valores y los capturamos todos juntos en una **varias** `variables`.

# %% [markdown]
# 3.2.1) Ejemplo 1: Devolviendo `strings`

# %%
def equipo():
    """ Función que no recibe parametros y
    devuelve los nombres de los integrantes del equipo
    """
    return 'Juan', 'Cecilia', 'Mariano', 'Luciano', 'Franco'

# Llamado con unpacking
integrante_1, integrante_2, integrante_3, integrante_4, integrante_5 = equipo()
print(f'El integrante 1 es: {integrante_1}')
print(f'El integrante 1 es: {integrante_2}')
print(f'El integrante 1 es: {integrante_3}')
print(f'El integrante 1 es: {integrante_4}')
print(f'El integrante 1 es: {integrante_5}')
# Out:
# El integrante 1 es: Juan
# El integrante 1 es: Cecilia
# El integrante 1 es: Mariano
# El integrante 1 es: Luciano
# El integrante 1 es: Franco

# %% [markdown]
# 3.2.2) Ejemplo 2: Devolviendo varias `tuplas`

# %%
def equipo_y_edades():
    """ Función que no recibe parametros y
    devuelve los nombres de los integrantes del equipo
    """
    return ('Juan', 10), ('Cecilia', 34),('Mariano',22),('Luciano',32),('Franco',30)
# Llamado con unpacking
tupla1, tupla2, tupla3, tupla4, tupla5= equipo_y_edades()
print(f'El integrante 1 es: {tupla1[0]} y su edad es {tupla1[1]}')
print(f'El integrante 1 es: {tupla2[0]} y su edad es {tupla2[1]}')
print(f'El integrante 1 es: {tupla3[0]} y su edad es {tupla3[1]}')
print(f'El integrante 1 es: {tupla4[0]} y su edad es {tupla4[1]}')
print(f'El integrante 1 es: {tupla5[0]} y su edad es {tupla5[1]}')
# Out:
# El integrante 1 es: Juan y su edad es 10
# El integrante 1 es: Cecilia y su edad es 34
# El integrante 1 es: Mariano y su edad es 22
# El integrante 1 es: Luciano y su edad es 32
# El integrante 1 es: Franco y su edad es 30
# ('Juan', 10)

# %% [markdown]
# # 📝 Ejercicios Parte 2

# %% [markdown]
# 👉 Parte 2 - Ejercicio de clase
#
# Definir una función `listar_articulos_a` que reciba como parametros una lista de articulos.
# - Aclarar que se espera un objeto de tipo `lista`.
# - La función debe contener un bucle `for` que recorra cada artículo y lo almacene en una lista en caso de comenzar con la letra a, independientemente de si el dato viene en mayúscula o minúscula.
#
# Nota: La `lista` que se usará para almacenar valores debe definirte previo a la función.

# %%
# Definimos una lista donde almacenar nuestras cotizaciones
lista = []
def listar_articulos_a(lista_articulos: list):
    """Funcion que recibe como parametro el nombre de un articulo (string) y lo
    anexa a una lista si cumple con la condición
    """
    for articulo in lista_articulos:
      primer_letra = articulo.lower().startswith("a")
      if primer_letra == True:
        lista.append(articulo)

    return lista

# Llamo a mi función
lista = listar_articulos_a(['Adaptador','Celular', 'Armario', 'Heladera','Auto',' Anana'])
print(lista)
# Out:
# ['Adaptador', 'Armario', 'Auto']

# %% [markdown]
# 🫴🏻 Parte 2 - Ejercicio de tarea 1
#
# Definir 3 diccionarios según la siguiente información del personal de una empresa:
#
# dicc1:
# - nombre: Luciano
# - apellido: Delgado
# - edad: 32
# - stack: Python
#
# dicc2:
# - nombre: Franco
# - apellido: Di Leo
# - edad: 30
# - stack: Javascript
#
# dicc3:
# - nombre: Cecilia
# - apellido: Enrich
# - edad: 34
# - stack: PowerBI
#
#
# Definir una funcion que itere cada uno de sus `items`
# - Cuando la `clave` del `item` recorrido sea el `nombre`, se debe almacenar en una variable para luego ser retornada en el `return`
# - Cuando la `clave` sea `stack` se debe evaluar qué perfil tiene la persona y también retornar junto con el nombre.
# Siendo el perfil definido según en qué categorización cae la tecnología manejada:
#
# - `('Python', 'SQL', 'MySQL', 'BigQuery', 'Spark' )`: Stack orientado a Data Scientist
# - `('HTML', 'Javascript', 'CSS', 'React', 'Django','Flask')`: Stack orientado a FrontEnd developer
# - `('PowerBI', 'Tableau', 'LookerStudio', 'Looker',)`: Stack orientado a Analytics

# %%
mi_dict_1 = {'nombre': 'Luciano', 'apellido': 'Delgado', 'edad': 32, 'stack': 'Python'}
mi_dict_2 = {'nombre': 'Franco', 'apellido': 'Di Leo', 'edad': 30, 'stack': 'Javascript'}
mi_dict_3 = {'nombre': 'Cecilia', 'apellido': 'Enrich', 'edad': 34, 'stack': 'PowerBI'}

def f1(diccionario):
  """Funcion que recibe como parametro un diccionario y devuelve el nombre y el stack al que
  está orientado la persona
  """
  for clave, valor in diccionario.items():
      # print(valor)
      if clave == 'nombre':
        nombre = valor
      if clave == 'stack' and valor in ('Python', 'SQL', 'MySQL', 'BigQuery', 'Spark' ):
          return nombre,'Stack orientado a Data Scientist'
      elif clave == 'stack' and valor in ('HTML', 'Javascript', 'CSS', 'React', 'Django','Flask'):
          return nombre, 'Stack orientado a FrontEnd developer'
      elif clave == 'stack' and valor in ('PowerBI', 'Tableau', 'LookerStudio', 'Looker',):
          return nombre,'Stack orientado a Analytics'
      else:
        continue

resultado1 = f1(mi_dict_1)
resultado2 = f1(mi_dict_2)
resultado3 = f1(mi_dict_3)
print(resultado1)
print(resultado2)
print(resultado3)
# Out:
# ('Luciano', 'Stack orientado a Data Scientist')
# ('Franco', 'Stack orientado a FrontEnd developer')
# ('Cecilia', 'Stack orientado a Analytics')

# %% [markdown]
# 🫴🏻 Parte 2 - Ejercicio de tarea 2
#
# Definir una función que reciba 2 parámetros `int` y realice la multiplicación de ellos.
#
# Luego se deben clafificar como `positivo/negativo/nulo` y retornar el resultado de la multiplicacion junto con la clasificación.
#
# Capturar el `return` de la función a través de la forma `unpacking`

# %%
def f2(a:int, b:int):
    """Funcion que recibe como parametro 2 valores enteros y devueve la multiplicacion
    junto con la clasificacion
    """
    mult = a*b
    if mult >0:
      return mult, 'Positivo'
    elif mult <0:
      return mult, 'Negativo'
    elif mult ==0:
      return mult, 'Nulo'

# Llamo a mi función con unpacking
resultado, clasificacion = f2(4,0)
print(resultado, clasificacion)
resultado, clasificacion = f2(5,3)
print(resultado, clasificacion)
resultado, clasificacion = f2(-2,3)
print(resultado, clasificacion)
# Out:
# 0 Nulo
# 15 Positivo
# -6 Negativo

# %% [markdown]
# # ⚡⚠️ Spoiler Alert! 😁😎

# %% [markdown]
# Si bien aún nos faltan ver conceptos como importar librerías y qué es un dataframe con sus métodos, está bueno resaltar que con lo visto hasta el momento podríamos tener una primera aproximación de cómo se crea y cual es la estructura de un dataframe lo cual es ampliamente utilizado en los análisis de datos.

# %%
# Importar librerías externas para reutilizar funciones que otroso hayan escrito ya.
import pandas as pd

# Definir el diccionario que representa las columnas del DataFrame
data = {
    'Nombre': ['Juan', 'María', 'Carlos', 'Laura', 'Ana'],
    'Edad': [25, 30, 35, 40, 45],
    'Puntuacion': [8.5, 7.2, 9.0, 6.5, 8.0]
}

# Crear el DataFrame
df = pd.DataFrame(data)

# Imprimir el DataFrame
print(f'Mi dataframe es \n{df}')
promedio_edad = df["Edad"].mean()
print(f'La edad promedio es: {promedio_edad}')
# Out:
# Mi dataframe es
#    Nombre  Edad  Puntuacion
# 0    Juan    25         8.5
# 1   María    30         7.2
# 2  Carlos    35         9.0
# 3   Laura    40         6.5
# 4     Ana    45         8.0
# La edad promedio es: 35.0
